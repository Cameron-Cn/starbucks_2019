# %% [markdown]
# # Starbucks TESTING DOCUMENT { &#9982; }  { &#74448; } { &#9878; }
# ### 2019 July 8
# `Cameron.Cn`
#
# ` Cuneform Sign Shim Times Mug | &#74448; `

# %%
# beginning off by importing our libraries, as per usual
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd

from shapely.geometry import Point  #transform latitude/longitude to geo-coordinate data
from geopandas.tools import geocode #get the latitude/longitude for a given address
from geopandas.tools import reverse_geocode 
from pandas import read_excel

# %matplotlib inline

# %%
# setting our data locations (all locations are ./)
sales1 = 'sales.csv'
direc1 = 'starbucksdirectory.csv'
starus1 = 'starbucksusa.csv'
starglob1 = 'storescountries.xlsx'
usMap1 = 'datasets_US_states(5m).json'
worMap1 = 'datasets_continents.json'

# %%
# we were having issues with reading, but it worked!
sales = pd.read_csv(sales1)
sales.head()
# Out:
#    Year  Revenue in billion U.S. dollars
# 0  2003                              4.1
# 1  2004                              5.3
# 2  2005                              6.4
# 3  2006                              7.8
# 4  2007                              9.4

# %%
# this is a potentially clunky method, but one that we have used for stability
direc = pd.read_csv(direc1)
starus = pd.read_csv(starus1)
starglob = pd.read_excel(starglob1)
usMap = gpd.read_file(usMap1)
worMap = gpd.read_file(worMap1)

# %%
# retaining only the continental US just in case -- but using a different variable so that we may have
# both to compare side-by-side later on
map48 = usMap.loc[usMap['NAME'].isin(['Alaska', 'Hawaii', 'Puerto Rico']) == False]
map48.head()
# Out:
#         GEO_ID STATE        NAME LSAD  CENSUSAREA  \
# 0  0400000US01    01     Alabama        50645.326
# 2  0400000US04    04     Arizona       113594.084
# 3  0400000US05    05    Arkansas        52035.477
# 4  0400000US06    06  California       155779.220
# 5  0400000US08    08    Colorado       103641.888
#
#                                             geometry
# 0  (POLYGON ((-88.124658 30.28364, -88.0868119999...
# 2  POLYGON ((-112.538593 37.000674, -112.534545 3...
# 3  POLYGON ((-94.042964 33.019219, -94.043036 33....
# 4  (POLYGON ((-122.421439 37.869969, -122.421341 ...
# 5  POLYGON ((-106.190554 40.997607, -106.061181 4...

# %%
# our world map (stored in JSON format)
worMap.plot()
map48.plot()

# %%
print(direc.head(),      # taking a look at the different dataframes we now have -- all at once
      '\n---------\n',   # \n is a non-printing <br> character in python's print() function
     sales.head(),
      '\n---------\n',
     starus.head(),
      '\n---------\n',
     starglob.head())
# Out:
#        Brand  Store Number        Store Name Ownership Type  \
# 0  Starbucks  47370-257954     Meritxell, 96       Licensed
# 1  Starbucks  22331-212325  Ajman Drive Thru       Licensed
# 2  Starbucks  47089-256771         Dana Mall       Licensed
# 3  Starbucks  22126-218024        Twofour 54       Licensed
# 4  Starbucks  17127-178586      Al Ain Tower       Licensed
#
#                     Street Address              City State/Province Country  \
# 0                Av. Meritxell, 96  Andorra la Vella              7      AD
# 1             1 Street 69, Al Jarf             Ajman             AJ      AE
# 2     Sheikh Khalifa Bin Zayed St.             Ajman             AJ      AE
# 3                  Al Salam Street         Abu Dhabi             AZ      AE
# 4  Khaldiya Area, Abu Dhabi Island         Abu Dhabi             AZ      AE
#
#   Postcode Phone Number                 Timezone  Longitude  Latitude
# 0    AD500    376818720  GMT+1:00 Europe/Andorra       1.53     42.51
# 1      NaN          NaN     GMT+04:00 Asia/Dubai      55.47     25.42
# 2      NaN          NaN     GMT+04:00 Asia/Dubai      55.47     25.39
# 3      NaN          NaN     GMT+04:00 Asia/Dubai      54.38     24.48
# 4      NaN          NaN     GMT+04:00 Asia/Dubai      54.54     24.51
# ---------
#     Year  Revenue in billion U.S. dollars
# 0  2003                              4.1
# 1  2004                              5.3
# 2  2005                              6.4
# 3  2006                              7.8
# 4  2007                              9.4
# ---------
#                    Store Name Ownership Type       City State/Province Country
# 0    Safeway-Anchorage #1809       Licensed  Anchorage             AK      US
# 1    Safeway-Anchorage #2628       Licensed  Anchorage             AK      US
# 2  Safeway - Anchorage #1813       Licensed  Anchorage             AK      US
# 3   100th & C St - Anchorage  Company Owned  Anchorage             AK      US
# 4       Old Seward & Diamond  Company Owned  Anchorage             AK      US
# ---------
#     Unnamed: 0                                         Unnamed: 1 Unnamed: 2
# 0         NaN                                                NaN        NaN
# 1         NaN                       Statistic as Excel data file        NaN
# 2         NaN  Countries with the largest number of Starbucks...        NaN
# 3         NaN                                        Access data        NaN
# 4         NaN                                                NaN        NaN

# %%
direc.head()
# Out:
#        Brand  Store Number        Store Name Ownership Type  \
# 0  Starbucks  47370-257954     Meritxell, 96       Licensed
# 1  Starbucks  22331-212325  Ajman Drive Thru       Licensed
# 2  Starbucks  47089-256771         Dana Mall       Licensed
# 3  Starbucks  22126-218024        Twofour 54       Licensed
# 4  Starbucks  17127-178586      Al Ain Tower       Licensed
#
#                     Street Address              City State/Province Country  \
# 0                Av. Meritxell, 96  Andorra la Vella              7      AD
# 1             1 Street 69, Al Jarf             Ajman             AJ      AE
# 2     Sheikh Khalifa Bin Zayed St.             Ajman             AJ      AE
# 3                  Al Salam Street         Abu Dhabi             AZ      AE
# 4  Khaldiya Area, Abu Dhabi Island         Abu Dhabi             AZ      AE
#
#   Postcode Phone Number                 Timezone  Longitude  Latitude
# 0    AD500    376818720  GMT+1:00 Europe/Andorra       1.53     42.51
# 1      NaN          NaN     GMT+04:00 Asia/Dubai      55.47     25.42
# 2      NaN          NaN     GMT+04:00 Asia/Dubai      55.47     25.39
# 3      NaN          NaN     GMT+04:00 Asia/Dubai      54.38     24.48
# 4      NaN          NaN     GMT+04:00 Asia/Dubai      54.54     24.51

# %%
direc.tail()
# Out:
#            Brand  Store Number      Store Name Ownership Type  \
# 25595  Starbucks  21401-212072             Rex       Licensed
# 25596  Starbucks  24010-226985        Panorama       Licensed
# 25597  Starbucks  47608-253804   Rosebank Mall       Licensed
# 25598  Starbucks  47640-253809    Menlyn Maine       Licensed
# 25599  Starbucks  47609-253286  Mall of Africa       Licensed
#
#                                           Street Address  \
# 25595  141 Nguyễn Huệ, Quận 1, Góc đường Pasteur và L...
# 25596  SN-44, Tòa Nhà Panorama, 208 Trần Văn Trà, Quận 7
# 25597          Cnr Tyrwhitt and Cradock Avenue, Rosebank
# 25598  Shop 61B, Central Square, Cnr Aramist & Coroba...
# 25599             Shop 2077, Upper Level, Waterfall City
#
#                         City State/Province Country Postcode  Phone Number  \
# 25595  Thành Phố Hồ Chí Minh             SG      VN    70000  08 3824 4668
# 25596  Thành Phố Hồ Chí Minh             SG      VN    70000  08 5413 8292
# 25597           Johannesburg             GT      ZA     2194   27873500159
# 25598                 Menlyn             GT      ZA      181           NaN
# 25599                Midrand             GT      ZA     1682   27873500215
#
#                              Timezone  Longitude  Latitude
# 25595          GMT+000000 Asia/Saigon     106.70     10.78
# 25596          GMT+000000 Asia/Saigon     106.71     10.72
# 25597  GMT+000000 Africa/Johannesburg      28.04    -26.15
# 25598  GMT+000000 Africa/Johannesburg      28.28    -25.79
# 25599  GMT+000000 Africa/Johannesburg      28.11    -26.02

# %%
direc.isnull().sum()
# Out:
# Brand                0
# Store Number         0
# Store Name           0
# Ownership Type       0
# Street Address       2
# City                15
# State/Province       0
# Country              0
# Postcode          1522
# Phone Number      6861
# Timezone             0
# Longitude            1
# Latitude             1
# dtype: int64

# %%
# where is our one store missing?
# It makes sense that other columns have issues--not every country
# has US Post codes!
noLat = direc.loc[direc['Longitude'].isnull()]
noLat
# Out:
#           Brand  Store Number           Store Name Ownership Type  \
# 8028  Starbucks  19773-160973  Yoido IFC Mall - 1F  Joint Venture
#
#                                       Street Address   City State/Province  \
# 8028  23 & 23-1, Yoido-Dong, Yongdongpo-Gu, 1F, #101  Seoul             11
#
#      Country Postcode Phone Number              Timezone  Longitude  Latitude
# 8028      KR  153-023          NaN  GMT+09:00 Asia/Seoul        NaN       NaN

# %%
# Seoul is missing...let's see if we can find it
seoulmiss = geocode("23 & 23-1, Yoido-Dong, Yongdongpo-Gu, 1F, #101, Seoul, South Korea", provider='arcgis')
seoulmiss
# Out:
#                               geometry             address
# 0  POINT (126.92903 37.52864000000005)  Yŏŭido-dong, Seoul

# %%
# So we have the 126.92 and 37.528 but are those similar to other Seoul-based
# locations? Let's check!
direc.loc[direc['City'] == 'Seoul']
# Out:
#           Brand  Store Number                     Store Name Ownership Type  \
# 7982  Starbucks  19176-199455                   Wolgae Emart  Joint Venture
# 7983  Starbucks  23428-230106        Olympic Park North Gate  Joint Venture
# 7984  Starbucks  49283-267704                    Mia Newtown  Joint Venture
# 7985  Starbucks  21320-211245                Yangjae Station  Joint Venture
# 7986  Starbucks  15565-163169               Apgujeong Center  Joint Venture
# 7987  Starbucks  16087-168288               Yonsei east gate  Joint Venture
# 7988  Starbucks  17225-180406                  Garak bondong  Joint Venture
# 7989  Starbucks  23237-228666                Myeongil E-Mart  Joint Venture
# 7990  Starbucks  47222-257364                      Hwagok DT  Joint Venture
# 7991  Starbucks  47985-260487      National Assemble Station  Joint Venture
# 7992  Starbucks  26442-237264      Seoul Nat'l Univ. Station  Joint Venture
# 7993  Starbucks  22505-221652                         Sadang  Joint Venture
# 7994  Starbucks  16277-170084              Dosan Main Street  Joint Venture
# 7995  Starbucks  26311-244130          Ulji Hospital Sageori  Joint Venture
# 7996  Starbucks  15044-157217         Mangwon Station Line 6  Joint Venture
# 7997  Starbucks  48539-263613               Gangdong Station  Joint Venture
# 7998  Starbucks  25153-238064                     Yeonhui DT  Joint Venture
# 7999  Starbucks  23137-228007          Hoegi Station Sageori  Joint Venture
# 8001  Starbucks  28879-251768                 Yangpyeongdong  Joint Venture
# 8002  Starbucks  22899-225644               Myeongdong Metro  Joint Venture
# 8003  Starbucks  25961-243009             Sangam Digitalcube  Joint Venture
# 8004  Starbucks  19604-202024                      Gwangnaru  Joint Venture
# 8005  Starbucks  23103-227306             Myongji University  Joint Venture
# 8006  Starbucks  47909-260164             Ulgiro 3ga station  Joint Venture
# 8007  Starbucks  20553-206767                 Itaewon Street  Joint Venture
# 8009  Starbucks  15046-157218                  Gasan V-Tower  Joint Venture
# 8010  Starbucks  26834-245764            Gwanghwamun Station  Joint Venture
# 8011  Starbucks  15834-165324               Hongdae-samgeory  Joint Venture
# 8012  Starbucks  23138-228004              Gangbyeon Station  Joint Venture
# 8013  Starbucks  17025-178332           Myeong Dong Entrance  Joint Venture
# ...         ...           ...                            ...            ...
# 8204  Starbucks  21095-209346           Samsung City Airport  Joint Venture
# 8205  Starbucks  19730-199447             Sinnonhyun station  Joint Venture
# 8206  Starbucks  22115-217785                        Dangsan  Joint Venture
# 8207  Starbucks  21362-212066                 Guro Digitalro  Joint Venture
# 8208  Starbucks  17585-183709                       Nowon KT  Joint Venture
# 8209  Starbucks  24063-234885                 Junggu Jeodong  Joint Venture
# 8210  Starbucks  24064-234884                  Jongno Susong  Joint Venture
# 8211  Starbucks  15535-162685              Chungmuro Station  Joint Venture
# 8212  Starbucks  49865-271165                   Sinsa garosu  Joint Venture
# 8213  Starbucks  23540-230965             Seokchon West Lake  Joint Venture
# 8214  Starbucks  23984-234305           Seoul Segwan Sageori  Joint Venture
# 8215  Starbucks  15396-160974                   Yoido Hosung  Joint Venture
# 8216  Starbucks  18257-185667  Suwon Sungkyunkwan University  Joint Venture
# 8217  Starbucks  18104-187924                    Jongro 2-ga  Joint Venture
# 8218  Starbucks  17533-183068                  Seokchon Lake  Joint Venture
# 8219  Starbucks  22015-217105                 Yeouido Ilshin  Joint Venture
# 8220  Starbucks  17035-178989               Sangbong-station  Joint Venture
# 8221  Starbucks  48860-265444      Daechi Eunma intersection  Joint Venture
# 8222  Starbucks  20937-209004             Seoul Womens Univ.  Joint Venture
# 8223  Starbucks  26626-244665                  Cheonho Rodeo  Joint Venture
# 8224  Starbucks  28011-249288    Olympic Park south 4th gate  Joint Venture
# 8225  Starbucks  22617-223144       Seoul Station Dongjadong  Joint Venture
# 8226  Starbucks  24242-236234                 Mullae Station  Joint Venture
# 8227  Starbucks  24465-228008                    Hwagok-dong  Joint Venture
# 8229  Starbucks  49917-271687                Yeongdeungpo kt  Joint Venture
# 8230  Starbucks  17769-180046                     Hapjung Xi  Joint Venture
# 8231  Starbucks  22504-221654               Seocho Jungangro  Joint Venture
# 8232  Starbucks  49868-270947                        Seogang  Joint Venture
# 8762  Starbucks  16975-177885              Kkachisan-station  Joint Venture
# 8763  Starbucks  21625-213666                  Gunja Station  Joint Venture
#
#                                          Street Address   City State/Province  \
# 7982                  333-1 Wolgae3dong, Nowongu, Seoul  Seoul             11
# 7983                      468 Seongnae-dong,Gangdong-gu  Seoul             11
# 7984                        812-2, Mia-dong, Gangbuk-gu  Seoul             11
# 7985                       14-4 Yangjae-dong, Seocho-gu  Seoul             11
# 7986  639-7, Shinsa-Dong, Gangnam-Gu, Yonsei Foundat...  Seoul             11
# 7987                      115 Daesin-Dong, Seodaemun-Gu  Seoul             11
# 7988                          97-4 Garak-dong Songpa-gu  Seoul             11
# 7989                      47-7 Myungil-dong,Gangdong-gu  Seoul             11
# 7990                   772-67,Hwagok 4-dong, Gangseo-gu  Seoul             11
# 7991                        Yoido 17-3, Yeongdeungpo-gu  Seoul             11
# 7992                   861-6, Bongcheon-dong, Gwanak-gu  Seoul             11
# 7993                    1060-10 Namhyeon-dong Gwanak-gu  Seoul             11
# 7994                    5 Nonhyeon-Dong, Gangnam-Gu, 2F  Seoul             11
# 7995                  59-8, Nonhyeon 2-dong, Gangnam-gu  Seoul             11
# 7996                       475-13, Seogyo-Dong, Mapo-Gu  Seoul             11
# 7997                          Cheonho-dong, Gangdong-gu  Seoul             11
# 7998                  87-26, Yeonhui-dong, Seodaemun-gu  Seoul             11
# 7999                  346-18, Hoegi-dong, Dongdaemun-gu  Seoul             11
# 8001            2, Yangpyeongdong 4-ga, Yeongdeungpo-gu  Seoul             11
# 8002                       199-33 Euljiro 2-ga, Jung-gu  Seoul             11
# 8003                         1647, Sangam-dong, Mapo-gu  Seoul             11
# 8004                  329-1 Gwangjang-dong, Gwangjin-gu  Seoul             11
# 8005                 344-1, Namgajwa-dong, Seodaemun-gu  Seoul             11
# 8006                         88-5,Euljiro 2-ga, Jung-gu  Seoul             11
# 8007                  657-104. Hannam 1-dong Yongsan-gu  Seoul             11
# 8009                   371-37, Gasan-Dong, Geumcheon-Gu  Seoul             11
# 8010                 249, Chungjindong, Jongrogu, Seoul  Seoul             11
# 8011                  86-22, Sangsu-Dong, Mapo-Gu, 1-2F  Seoul             11
# 8012                     589-10, Guui-dong, Gwangjin-gu  Seoul             11
# 8013                       85-5 Myeongdong-1ga, Jung-gu  Seoul             11
# ...                                                 ...    ...            ...
# 8204  154-10, Samseong1-dong, Gangnam-gu, Yungjeon B...  Seoul             11
# 8205                       809-10 yeoksamdong gangnamgu  Seoul             11
# 8206            338-1 Dangsan-dong 6-ga Yeongdeungpo-gu  Seoul             11
# 8207              Ace Techno 8-cha Guro 3-dong, Guro-gu  Seoul             11
# 8208                         723, Sanggaedong, Nowon-gu  Seoul             11
# 8209                   24-1,25-1, Jeodong 2-ga, Jung-gu  Seoul             11
# 8210    19, Cheongjin-dong, Jongno-gu, Chungmu Building  Seoul             11
# 8211                         Pil-Dong 2-Ga, Jung-Gu, 1F  Seoul             11
# 8212                 533-11 Sinsa-dong,Gangnam-gu,Seoul  Seoul             11
# 8213                        130-2 Samjeondong,Songpa-gu  Seoul             11
# 8214   238-5, Nonhyun-dong, Gangnam-gu, Hosung Building  Seoul             11
# 8215                44-22 Yeouido-Dong, Yeongdeungpo-Gu  Seoul             11
# 8216             285-6, Yuljeon-dong, Jangan-gu, Jangan  Seoul             11
# 8217                    75-4, Insadong, Jongrogu, Seoul  Seoul             11
# 8218                         7-4 Songpa-dong, Songpa-gu  Seoul             11
# 8219           15-15. Yeouido-dong Yeongdeungpo-guSeoul  Seoul             11
# 8220                  100-2, Sangbong-dong, Jungrang-gu  Seoul             11
# 8221                       941-19 Daechidong, Gangnamgu  Seoul             11
# 8222              621 Hwarang-ro Nowon-gu, Seoul, Korea  Seoul             11
# 8223                  453-14, Cheonho dong, Gangdong-gu  Seoul             11
# 8224                        180-8 Bangi-dong, Songpa-gu  Seoul             11
# 8225                     14-25, Dongja-dong, Yongsan-gu  Seoul             11
# 8226            55-5, Mullae-dong 3-ga, Yeongdeungpo-gu  Seoul             11
# 8227                   1073-10, Hwagok-dong, Gangseo-gu  Seoul             11
# 8229       Yeongdeungpo-dong is 8 35-1, Yeongdeungpo-gu  Seoul             11
# 8230                           418, Hapjungdong, Mapogu  Seoul             11
# 8231                        52-6, Banpo-dong, Seocho-gu  Seoul             11
# 8232                        130 Changjeon-dong, Mapo-gu  Seoul             11
# 8762                     343-1, Hwagok-dong, Gangseo-gu  Seoul             41
# 8763                     478-5, Gunja-dong, Gwangjin-gu  Seoul             41
#
#      Country Postcode Phone Number              Timezone  Longitude  Latitude
# 7982      KR  139-050          NaN  GMT+09:00 Asia/Seoul     127.06     37.63
# 7983      KR  134-848          NaN  GMT+09:00 Asia/Seoul     127.13     37.53
# 7984      KR     1195          NaN  GMT+09:00 Asia/Seoul     127.02     37.62
# 7985      KR  137-888          NaN  GMT+09:00 Asia/Seoul     127.04     37.48
# 7986      KR  135-896          NaN  GMT+09:00 Asia/Seoul     127.04     37.53
# 7987      KR  120-160          NaN  GMT+09:00 Asia/Seoul     126.95     37.57
# 7988      KR  138-804          NaN  GMT+09:00 Asia/Seoul     127.12     37.49
# 7989      KR  134-825          NaN  GMT+09:00 Asia/Seoul     127.16     37.55
# 7990      KR     7741          NaN  GMT+09:00 Asia/Seoul     126.86     37.54
# 7991      KR     7236          NaN  GMT+09:00 Asia/Seoul     126.92     37.53
# 7992      KR  151-811          NaN  GMT+09:00 Asia/Seoul     126.95     37.48
# 7993      KR  151-800          NaN  GMT+09:00 Asia/Seoul     126.98     37.48
# 7994      KR  135-812          NaN  GMT+09:00 Asia/Seoul     127.02     37.52
# 7995      KR  135-816          NaN  GMT+09:00 Asia/Seoul     127.03     37.52
# 7996      KR  121-210          NaN  GMT+09:00 Asia/Seoul     126.91     37.56
# 7997      KR  134-020          NaN  GMT+09:00 Asia/Seoul     127.13     37.54
# 7998      KR  120-829          NaN  GMT+09:00 Asia/Seoul     126.93     37.57
# 7999      KR  130-881          NaN  GMT+09:00 Asia/Seoul     127.06     37.59
# 8001      KR  150-967          NaN  GMT+09:00 Asia/Seoul     126.90     37.53
# 8002      KR  100-845          NaN  GMT+09:00 Asia/Seoul     126.98     37.57
# 8003      KR  121-904          NaN  GMT+09:00 Asia/Seoul     126.89     37.58
# 8004      KR  143-810          NaN  GMT+09:00 Asia/Seoul     127.62     37.33
# 8005      KR  120-807          NaN  GMT+09:00 Asia/Seoul     126.92     37.58
# 8006      KR  100-845          NaN  GMT+09:00 Asia/Seoul     126.99     37.57
# 8007      KR  140-887          NaN  GMT+09:00 Asia/Seoul     126.60     37.33
# 8009      KR  153-023          NaN  GMT+09:00 Asia/Seoul     126.88     37.48
# 8010      KR  110-130          NaN  GMT+09:00 Asia/Seoul     126.98     37.57
# 8011      KR  121-828          NaN  GMT+09:00 Asia/Seoul     126.92     37.55
# 8012      KR  143-724          NaN  GMT+09:00 Asia/Seoul     127.09     37.54
# 8013      KR  100-021          NaN  GMT+09:00 Asia/Seoul     126.98     37.56
# ...      ...      ...          ...                   ...        ...       ...
# 8204      KR  135-879          NaN  GMT+09:00 Asia/Seoul     127.33     37.30
# 8205      KR  135-080          NaN  GMT+09:00 Asia/Seoul     127.03     37.50
# 8206      KR  150-810          NaN  GMT+09:00 Asia/Seoul     126.90     37.54
# 8207      KR  152-780          NaN  GMT+09:00 Asia/Seoul     126.73     37.34
# 8208      KR  139-200          NaN  GMT+09:00 Asia/Seoul     127.06     37.65
# 8209      KR  100-748          NaN  GMT+09:00 Asia/Seoul     126.99     37.56
# 8210      KR  110-130          NaN  GMT+09:00 Asia/Seoul     126.98     37.57
# 8211      KR  100-272          NaN  GMT+09:00 Asia/Seoul     126.99     37.56
# 8212      KR     6028          NaN  GMT+09:00 Asia/Seoul     127.02     37.52
# 8213      KR  138-840          NaN  GMT+09:00 Asia/Seoul     127.10     37.51
# 8214      KR  135-830          NaN  GMT+09:00 Asia/Seoul     127.04     37.51
# 8215      KR  150-890          NaN  GMT+09:00 Asia/Seoul     126.93     37.52
# 8216      KR  440-825          NaN  GMT+09:00 Asia/Seoul     126.97     37.30
# 8217      KR  110-290          NaN  GMT+09:00 Asia/Seoul     126.99     37.57
# 8218      KR  138-848          NaN  GMT+09:00 Asia/Seoul     127.62     37.30
# 8219      KR  150-872          NaN  GMT+09:00 Asia/Seoul     126.92     37.53
# 8220      KR  143-200          NaN  GMT+09:00 Asia/Seoul     127.09     37.60
# 8221      KR     6209          NaN  GMT+09:00 Asia/Seoul     127.06     37.50
# 8222      KR  139-774          NaN  GMT+09:00 Asia/Seoul     127.53     37.37
# 8223      KR  134-864          NaN  GMT+09:00 Asia/Seoul     127.13     37.54
# 8224      KR  138-830          NaN  GMT+09:00 Asia/Seoul     127.12     37.52
# 8225      KR  140-819          NaN  GMT+09:00 Asia/Seoul     126.97     37.55
# 8226      KR  150-835          NaN  GMT+09:00 Asia/Seoul     126.90     37.52
# 8227      KR  157-925          NaN  GMT+09:00 Asia/Seoul     126.84     37.54
# 8229      KR     7228          NaN  GMT+09:00 Asia/Seoul     126.91     37.53
# 8230      KR  121-220          NaN  GMT+09:00 Asia/Seoul     126.91     37.55
# 8231      KR      NaN          NaN  GMT+09:00 Asia/Seoul     127.01     37.50
# 8232      KR     4065          NaN  GMT+09:00 Asia/Seoul     126.93     37.55
# 8762      KR  157-010          NaN  GMT+09:00 Asia/Seoul     126.85     37.53
# 8763      KR  143-150          NaN  GMT+09:00 Asia/Seoul     127.44     37.33
#
# [243 rows x 13 columns]

# %%
# now we can only do this because there is ONE value missing
# DO NOT DO THIS IF YOU HAVE MULTIPLE MISSING VALUES

direc['Longitude'].fillna('126.93', inplace=True)
direc['Latitude'].fillna('37.53', inplace=True)

# %%
direc.isnull().sum()
# Out:
# Brand                0
# Store Number         0
# Store Name           0
# Ownership Type       0
# Street Address       2
# City                15
# State/Province       0
# Country              0
# Postcode          1522
# Phone Number      6861
# Timezone             0
# Longitude            0
# Latitude             0
# dtype: int64

# %%
# our Long/Lat are objects, which prevents Point assigning later on if we let them
# stay that way
direc['Longitude'] = direc['Longitude'].astype(float)
print("Done")
# Out:
# Done

# %%
direc['Latitude'] = direc['Latitude'].astype(float)
print("Done")
# Out:
# Done

# %%
direc['Longitude'].dtype
# Out:
# dtype('float64')

# %%
# Making a single column to hold location data (long/lat)
direc['Coordinates'] = list(direc[['Longitude', 'Latitude']].values)
direc.head()
# Out:
#        Brand  Store Number        Store Name Ownership Type  \
# 0  Starbucks  47370-257954     Meritxell, 96       Licensed
# 1  Starbucks  22331-212325  Ajman Drive Thru       Licensed
# 2  Starbucks  47089-256771         Dana Mall       Licensed
# 3  Starbucks  22126-218024        Twofour 54       Licensed
# 4  Starbucks  17127-178586      Al Ain Tower       Licensed
#
#                     Street Address              City State/Province Country  \
# 0                Av. Meritxell, 96  Andorra la Vella              7      AD
# 1             1 Street 69, Al Jarf             Ajman             AJ      AE
# 2     Sheikh Khalifa Bin Zayed St.             Ajman             AJ      AE
# 3                  Al Salam Street         Abu Dhabi             AZ      AE
# 4  Khaldiya Area, Abu Dhabi Island         Abu Dhabi             AZ      AE
#
#   Postcode Phone Number                 Timezone  Longitude  Latitude  \
# 0    AD500    376818720  GMT+1:00 Europe/Andorra       1.53     42.51
# 1      NaN          NaN     GMT+04:00 Asia/Dubai      55.47     25.42
# 2      NaN          NaN     GMT+04:00 Asia/Dubai      55.47     25.39
# 3      NaN          NaN     GMT+04:00 Asia/Dubai      54.38     24.48
# 4      NaN          NaN     GMT+04:00 Asia/Dubai      54.54     24.51
#
#       Coordinates
# 0   [1.53, 42.51]
# 1  [55.47, 25.42]
# 2  [55.47, 25.39]
# 3  [54.38, 24.48]
# 4  [54.54, 24.51]

# %%
# checking the data type
direc['Coordinates'].dtype
# Out:
# dtype('O')

# %%
direc['Coordinates'].head(15)
# Out:
# 0      [1.53, 42.51]
# 1     [55.47, 25.42]
# 2     [55.47, 25.39]
# 3     [54.38, 24.48]
# 4     [54.54, 24.51]
# 5      [54.49, 24.4]
# 6      [54.49, 24.4]
# 7     [54.61, 24.46]
# 8     [55.69, 24.19]
# 9     [54.38, 24.48]
# 10    [54.34, 24.47]
# 11    [54.37, 24.49]
# 12    [55.69, 24.19]
# 13      [54.7, 24.3]
# 14     [54.6, 24.48]
# Name: Coordinates, dtype: object

# %%
# we have to convert it to a point
direc['Coordinates'] = direc['Coordinates'].apply(Point)
direc.head()
# Out:
#        Brand  Store Number        Store Name Ownership Type  \
# 0  Starbucks  47370-257954     Meritxell, 96       Licensed
# 1  Starbucks  22331-212325  Ajman Drive Thru       Licensed
# 2  Starbucks  47089-256771         Dana Mall       Licensed
# 3  Starbucks  22126-218024        Twofour 54       Licensed
# 4  Starbucks  17127-178586      Al Ain Tower       Licensed
#
#                     Street Address              City State/Province Country  \
# 0                Av. Meritxell, 96  Andorra la Vella              7      AD
# 1             1 Street 69, Al Jarf             Ajman             AJ      AE
# 2     Sheikh Khalifa Bin Zayed St.             Ajman             AJ      AE
# 3                  Al Salam Street         Abu Dhabi             AZ      AE
# 4  Khaldiya Area, Abu Dhabi Island         Abu Dhabi             AZ      AE
#
#   Postcode Phone Number                 Timezone  Longitude  Latitude  \
# 0    AD500    376818720  GMT+1:00 Europe/Andorra       1.53     42.51
# 1      NaN          NaN     GMT+04:00 Asia/Dubai      55.47     25.42
# 2      NaN          NaN     GMT+04:00 Asia/Dubai      55.47     25.39
# 3      NaN          NaN     GMT+04:00 Asia/Dubai      54.38     24.48
# 4      NaN          NaN     GMT+04:00 Asia/Dubai      54.54     24.51
#
#            Coordinates
# 0   POINT (1.53 42.51)
# 1  POINT (55.47 25.42)
# 2  POINT (55.47 25.39)
# 3  POINT (54.38 24.48)
# 4  POINT (54.54 24.51)

# %%
geo_direc = gpd.GeoDataFrame(direc, geometry='Coordinates')
geo_direc.head()
# Out:
#        Brand  Store Number        Store Name Ownership Type  \
# 0  Starbucks  47370-257954     Meritxell, 96       Licensed
# 1  Starbucks  22331-212325  Ajman Drive Thru       Licensed
# 2  Starbucks  47089-256771         Dana Mall       Licensed
# 3  Starbucks  22126-218024        Twofour 54       Licensed
# 4  Starbucks  17127-178586      Al Ain Tower       Licensed
#
#                     Street Address              City State/Province Country  \
# 0                Av. Meritxell, 96  Andorra la Vella              7      AD
# 1             1 Street 69, Al Jarf             Ajman             AJ      AE
# 2     Sheikh Khalifa Bin Zayed St.             Ajman             AJ      AE
# 3                  Al Salam Street         Abu Dhabi             AZ      AE
# 4  Khaldiya Area, Abu Dhabi Island         Abu Dhabi             AZ      AE
#
#   Postcode Phone Number                 Timezone  Longitude  Latitude  \
# 0    AD500    376818720  GMT+1:00 Europe/Andorra       1.53     42.51
# 1      NaN          NaN     GMT+04:00 Asia/Dubai      55.47     25.42
# 2      NaN          NaN     GMT+04:00 Asia/Dubai      55.47     25.39
# 3      NaN          NaN     GMT+04:00 Asia/Dubai      54.38     24.48
# 4      NaN          NaN     GMT+04:00 Asia/Dubai      54.54     24.51
#
#            Coordinates
# 0   POINT (1.53 42.51)
# 1  POINT (55.47 25.42)
# 2  POINT (55.47 25.39)
# 3  POINT (54.38 24.48)
# 4  POINT (54.54 24.51)

# %%
x = geo_direc['Longitude']
y = geo_direc['Latitude']

plt.scatter(x,y, data = geo_direc)

# %%
fig, ax = plt.subplots(1, figsize=(20,20))
basemap = worMap.plot(ax=ax, color='grey')
geo_direc.plot(ax=basemap, marker='.', markersize=20)

ax.axis('off')
ax.set_title("Starbucks Stores Globally", fontsize=24)
#plt.savefig("starbucks_world-map.png")
# Out:
# Text(0.5, 1.0, 'Starbucks Stores Globally')

# %%
starusa = geo_direc[geo_direc['Country'] == 'US']
starusa.head()
# Out:
#            Brand  Store Number                 Store Name Ownership Type  \
# 11964  Starbucks   3513-125945    Safeway-Anchorage #1809       Licensed
# 11965  Starbucks   74352-84449    Safeway-Anchorage #2628       Licensed
# 11966  Starbucks  12449-152385  Safeway - Anchorage #1813       Licensed
# 11967  Starbucks  24936-233524   100th & C St - Anchorage  Company Owned
# 11968  Starbucks    8973-85630       Old Seward & Diamond  Company Owned
#
#                                           Street Address       City  \
# 11964                               5600 Debarr Rd Ste 9  Anchorage
# 11965                                     1725 Abbott Rd  Anchorage
# 11966                                    1501 Huffman Rd  Anchorage
# 11967  320 W. 100th Ave, 100, Southgate Shopping Ctr ...  Anchorage
# 11968                                 1005 E Dimond Blvd  Anchorage
#
#       State/Province Country   Postcode    Phone Number  \
# 11964             AK      US  995042300    907-339-0900
# 11965             AK      US  995073444    907-339-2800
# 11966             AK      US  995153596    907-339-1300
# 11967             AK      US      99515  (907) 227-9631
# 11968             AK      US  995152050    907-344-4160
#
#                           Timezone  Longitude  Latitude            Coordinates
# 11964  GMT-09:00 America/Anchorage    -149.78     61.21  POINT (-149.78 61.21)
# 11965  GMT-09:00 America/Anchorage    -149.84     61.14  POINT (-149.84 61.14)
# 11966  GMT-09:00 America/Anchorage    -149.85     61.11  POINT (-149.85 61.11)
# 11967  GMT-09:00 America/Anchorage    -149.89     61.13  POINT (-149.89 61.13)
# 11968  GMT-09:00 America/Anchorage    -149.86     61.14  POINT (-149.86 61.14)

# %%
starusa.plot()

# %%
fig, ax = plt.subplots(1, figsize=(50,50))
basemap = usMap.plot(ax=ax, color='grey')
starusa.plot(ax=basemap, marker='.', markersize=20)

ax.axis('off')
ax.set_title("Starbucks Stores In the US", fontsize=24)
#plt.savefig("starbucks_usa-map.png")
# Out:
# Text(0.5, 1.0, 'Starbucks Stores In the US')

# %%
staruscont = starusa.loc[starusa['State/Province'].isin(['AK','HI']) == False]
staruscont.head()
# Out:
#            Brand  Store Number               Store Name Ownership Type  \
# 12013  Starbucks   76795-96265  Target Alabaster T-2276       Licensed
# 12014  Starbucks   13210-95453         I-65 & US HWY 31  Company Owned
# 12015  Starbucks  10796-102254     Hwy 119 & Kent Dairy  Company Owned
# 12016  Starbucks  10248-100069           Hwy 72 & Braly  Company Owned
# 12017  Starbucks  47255-121766   Kroger-Auburn, AL #260       Licensed
#
#               Street Address       City State/Province Country   Postcode  \
# 12013      250 S Colonial Dr  Alabaster             AL      US  350074657
# 12014  345 South Colonial Dr  Alabaster             AL      US  350074690
# 12015     2171 Kent Dairy Rd  Alabaster             AL      US  350075387
# 12016       1286 Hwy 72 East     Athens             AL      US  356114404
# 12017            300 Dean Rd     Auburn             AL      US  368304404
#
#        Phone Number                   Timezone  Longitude  Latitude  \
# 12013  205-564-2608  GMT-06:00 America/Chicago     -86.81     33.23
# 12014  205-664-3797  GMT-06:00 America/Chicago     -86.80     33.22
# 12015  205-685-9705  GMT-06:00 America/Chicago     -86.83     33.21
# 12016  256-230-9385  GMT-06:00 America/Chicago     -86.95     34.78
# 12017  334-821-1325  GMT-06:00 America/Chicago     -85.46     32.61
#
#                             Coordinates
# 12013              POINT (-86.81 33.23)
# 12014               POINT (-86.8 33.22)
# 12015              POINT (-86.83 33.21)
# 12016              POINT (-86.95 34.78)
# 12017  POINT (-85.45999999999999 32.61)

# %%
map48 = usMap.loc[usMap['NAME'].isin(['Alaska', 'Hawaii', 'Puerto Rico']) == False]

# %%
fig, ax = plt.subplots(1, figsize=(20,20))
basemap = map48.plot(ax=ax, color='grey')
staruscont.plot(ax=basemap, marker='.', markersize=20)

ax.axis('off')
ax.set_title("Starbucks Stores on Continental US", fontsize=24)
#plt.savefig("starbucks_cont-us-map.png")
# Out:
# Text(0.5, 1.0, 'Starbucks Stores on Continental US')

# %%
geo_direc.to_csv("starbucks_revised_location.csv", index=False, header=True)

# %%
staruscont.to_csv("starbucks_revised_cont-us.csv", index=False, header=True)

# %%
direc.to_csv("starbucks_revised_directory.csv", index=False, header=True)

# %%
print("Done")
# Out:
# Done

# %%
import pandas as pd
import numpy as np
import seaborn; seaborn.set()
import matplotlib.pyplot as plt

from datetime import datetime

# %matplotlib inline

# %%
location = "Starbucks_Financials.csv"
df = pd.read_csv(location)

# %%
df.head()
# Out:
#         Fiscal Period    200803    200806    200809    200812    200903  \
# 0             Revenue      2526      2574    2515.4    2615.2    2333.3
# 1  Cost of Goods Sold  2,116.60  1,163.10  1,189.50  1,196.80  1,043.50
# 2        Gross Profit     409.4  1,410.90  1,325.90  1,418.40  1,289.80
# 3          Net Income     108.7      -6.7       5.4      64.3        25
# 4         EPS (Basic)     0.075    -0.005     0.005     0.045     0.015
#
#      200906    200909    200912    201003  ...    201612    201703    201706  \
# 0    2403.9    2422.2    2722.7    2534.7  ...    5732.9      5294    5661.5
# 1  1,043.40  1,041.20  1,145.70  1,064.10  ...  3,933.20  3,727.60  3,878.00
# 2  1,360.50  1,381.00  1,577.00  1,470.60  ...  1,799.70  1,566.40  1,783.50
# 3     151.5       150     241.5     217.3  ...     751.8     652.8     691.6
# 4       0.1       0.1      0.16     0.145  ...      0.52      0.45      0.48
#
# ...

# %%
df = df.T

# %%
df.head()
# Out:
#                    0                   1             2           3    \
# Fiscal Period  Revenue  Cost of Goods Sold  Gross Profit  Net Income
# 200803            2526            2,116.60         409.4       108.7
# 200806            2574            1,163.10      1,410.90        -6.7
# 200809          2515.4            1,189.50      1,325.90         5.4
# 200812          2615.2            1,196.80      1,418.40        64.3
#
#                        4    5    6    7    8    9    ...  146  147  148  149  \
# Fiscal Period  EPS (Basic)  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN
# 200803               0.075  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN
# 200806              -0.005  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN
# 200809               0.005  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN
# 200812               0.045  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN
#
#                150  151  152  153  154  155
# ...

# %%
result = df.reset_index()

# %%
result.head()
# Out:
#            index        0                   1             2           3  \
# 0  Fiscal Period  Revenue  Cost of Goods Sold  Gross Profit  Net Income
# 1         200803     2526            2,116.60         409.4       108.7
# 2         200806     2574            1,163.10      1,410.90        -6.7
# 3         200809   2515.4            1,189.50      1,325.90         5.4
# 4         200812   2615.2            1,196.80      1,418.40        64.3
#
#              4    5    6    7    8  ...  146  147  148  149  150  151  152  \
# 0  EPS (Basic)  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1        0.075  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2       -0.005  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3        0.005  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4        0.045  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#    153  154  155
# 0  NaN  NaN  NaN
# 1  NaN  NaN  NaN
# 2  NaN  NaN  NaN
# ...

# %%
result.columns = result.iloc[0]

# %%
result.head()
# Out:
# 0  Fiscal Period  Revenue  Cost of Goods Sold  Gross Profit  Net Income  \
# 0  Fiscal Period  Revenue  Cost of Goods Sold  Gross Profit  Net Income
# 1         200803     2526            2,116.60         409.4       108.7
# 2         200806     2574            1,163.10      1,410.90        -6.7
# 3         200809   2515.4            1,189.50      1,325.90         5.4
# 4         200812   2615.2            1,196.80      1,418.40        64.3
#
# 0  EPS (Basic)  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  \
# 0  EPS (Basic)  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1        0.075  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2       -0.005  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3        0.005  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4        0.045  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# 0  NaN  NaN  NaN
# 0  NaN  NaN  NaN
# 1  NaN  NaN  NaN
# 2  NaN  NaN  NaN
# ...

# %%
result = result.drop(result.index[0])

# %%
result.head()
# Out:
# 0 Fiscal Period Revenue Cost of Goods Sold Gross Profit Net Income  \
# 1        200803    2526           2,116.60        409.4      108.7
# 2        200806    2574           1,163.10     1,410.90       -6.7
# 3        200809  2515.4           1,189.50     1,325.90        5.4
# 4        200812  2615.2           1,196.80     1,418.40       64.3
# 5        200903  2333.3           1,043.50     1,289.80         25
#
# 0 EPS (Basic)  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  \
# 1       0.075  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2      -0.005  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3       0.005  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4       0.045  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 5       0.015  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# 0  NaN  NaN  NaN
# 1  NaN  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  NaN  NaN
# 4  NaN  NaN  NaN
# 5  NaN  NaN  NaN
#
# ...

# %%
result['Fiscal Period'].head()
# Out:
# 1    200803
# 2    200806
# 3    200809
# 4    200812
# 5    200903
# Name: Fiscal Period, dtype: object

# %%
#datetime test
t = 200705
pd.to_datetime(str(t), format='%Y%m')
# Out:
# Timestamp('2007-05-01 00:00:00')

# %%
result['Fiscal Period'] = pd.to_datetime(result['Fiscal Period'].astype(str), format='%Y%m')

# %%
result
# Out:
# 0  Fiscal Period Revenue Cost of Goods Sold Gross Profit Net Income  \
# 1     2008-03-01    2526           2,116.60        409.4      108.7
# 2     2008-06-01    2574           1,163.10     1,410.90       -6.7
# 3     2008-09-01  2515.4           1,189.50     1,325.90        5.4
# 4     2008-12-01  2615.2           1,196.80     1,418.40       64.3
# 5     2009-03-01  2333.3           1,043.50     1,289.80         25
# 6     2009-06-01  2403.9           1,043.40     1,360.50      151.5
# 7     2009-09-01  2422.2           1,041.20     1,381.00        150
# 8     2009-12-01  2722.7           1,145.70     1,577.00      241.5
# 9     2010-03-01  2534.7           1,064.10     1,470.60      217.3
# 10    2010-06-01    2612           1,076.20     1,535.80      207.9
# 11    2010-09-01    2838           1,130.50     1,707.50      278.9
# 12    2010-12-01  2950.8           1,192.30     1,758.50      346.6
# 13    2011-03-01  2785.7           1,171.20     1,614.50      261.6
# ...

# %%
result['Fiscal Period']
# Out:
# 1    2008-03-01
# 2    2008-06-01
# 3    2008-09-01
# 4    2008-12-01
# 5    2009-03-01
# 6    2009-06-01
# 7    2009-09-01
# 8    2009-12-01
# 9    2010-03-01
# 10   2010-06-01
# 11   2010-09-01
# 12   2010-12-01
# 13   2011-03-01
# 14   2011-06-01
# 15   2011-09-01
# 16   2011-12-01
# 17   2012-03-01
# 18   2012-06-01
# 19   2012-09-01
# 20   2012-12-01
# 21   2013-03-01
# 22   2013-06-01
# 23   2013-09-01
# 24   2013-12-01
# 25   2014-03-01
# 26   2014-06-01
# 27   2014-09-01
# 28   2014-12-01
# 29   2015-03-01
# 30   2015-06-01
# 31   2015-09-01
# 32   2015-12-01
# 33   2016-03-01
# 34   2016-06-01
# 35   2016-09-01
# 36   2016-12-01
# 37   2017-03-01
# 38   2017-06-01
# 39   2017-09-01
# 40   2017-12-01
# 41   2018-03-01
# 42   2018-06-01
# 43   2018-09-01
# 44   2018-12-01
# 45   2019-03-01
# Name: Fiscal Period, dtype: datetime64[ns]

# %%
result['Revenue']
# Out:
# 1       2526
# 2       2574
# 3     2515.4
# 4     2615.2
# 5     2333.3
# 6     2403.9
# 7     2422.2
# 8     2722.7
# 9     2534.7
# 10      2612
# 11      2838
# 12    2950.8
# 13    2785.7
# 14    2932.2
# 15    3031.7
# 16    3435.9
# 17    3195.9
# 18    3303.6
# 19    3341.4
# 20    3793.2
# 21    3549.6
# 22    3735.3
# 23    3788.7
# 24    4239.6
# 25    3873.8
# 26    4153.7
# 27    4180.7
# 28    4803.2
# 29    4563.5
# 30    4881.2
# 31    4914.8
# 32    5373.5
# 33    4993.2
# 34      5238
# 35    5711.2
# 36    5732.9
# 37      5294
# 38    5661.5
# 39    5698.3
# 40    6073.7
# 41    6031.8
# 42    6310.3
# 43    6303.6
# 44    6632.7
# 45    6305.9
# Name: Revenue, dtype: object

# %%
#groupby Fiscal year and Revenue
df_revenue = result.groupby(['Fiscal Period','Revenue']).size().reset_index()
#df.groupby(['col5','col2']).size().reset_index().groupby('col2')[[0]].max()

# %%
df_revenue.head()
# Out:
#   Fiscal Period Revenue  0
# 0    2008-03-01    2526  1
# 1    2008-06-01    2574  1
# 2    2008-09-01  2515.4  1
# 3    2008-12-01  2615.2  1
# 4    2009-03-01  2333.3  1

# %%
df_revenue.tail()
# Out:
#    Fiscal Period Revenue  0
# 40    2018-03-01  6031.8  1
# 41    2018-06-01  6310.3  1
# 42    2018-09-01  6303.6  1
# 43    2018-12-01  6632.7  1
# 44    2019-03-01  6305.9  1

# %%
df_revenue.set_index(['Fiscal Period'], inplace=True)
df_revenue.head()
# Out:
#                Revenue  0
# Fiscal Period
# 2008-03-01      2526.0  1
# 2008-06-01      2574.0  1
# 2008-09-01      2515.4  1
# 2008-12-01      2615.2  1
# 2009-03-01      2333.3  1

# %%
y = df_revenue['Revenue']

# %%
y.head()
# Out:
# Fiscal Period
# 2008-03-01    2526.0
# 2008-06-01    2574.0
# 2008-09-01    2515.4
# 2008-12-01    2615.2
# 2009-03-01    2333.3
# Name: Revenue, dtype: float64

# %%
df_revenue['Revenue']= df_revenue.Revenue.astype(float)

# %%
df_revenue.dtypes
# Out:
# Revenue    float64
# 0            int64
# dtype: object

# %%
y = df_revenue['Revenue']

# %%
y.plot(figsize=(15, 6))
plt.savefig('Sbux_Rev.png')

# %%
import warnings
import itertools
import numpy as np
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')
import pandas as pd
import statsmodels.api as sm
import matplotlib

# %%
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(y,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            results = mod.fit()

            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:864.2406114212955
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:1452.257298895704
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:550.7990489270701
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:473.4319307741284
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:454.51292127102874
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:320.21837879040515
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:818.6797614811278
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:2728.3706559496836
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:503.63040561717264
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:464.1012532225315
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:430.45533734815893
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:314.46237292292756
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:607.0996188205927
# ARIMA(0, 1, 0)x(0, 0, 1, 12)12 - AIC:1425.245917748723
# ARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:411.07678348767377
# ARIMA(0, 1, 0)x(1, 0, 0, 12)12 - AIC:425.321883888803
# ARIMA(0, 1, 0)x(1, 0, 1, 12)12 - AIC:1336.016835671076
# ...

# %%
mod = sm.tsa.statespace.SARIMAX(y,
                                order=(1, 1, 1),
                                seasonal_order=(1, 1, 0, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)

results = mod.fit()

print(results.summary().tables[1])
# Out:
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0054      0.585     -0.009      0.993      -1.151       1.141
# ma.L1         -0.4263      0.577     -0.739      0.460      -1.557       0.705
# ar.S.L12      -0.0787      0.265     -0.297      0.766      -0.598       0.441
# sigma2      2.626e+04   8558.907      3.068      0.002    9484.194     4.3e+04
# ...

# %%
results.plot_diagnostics(figsize=(16, 8))

# %%
pred = results.get_prediction(start=pd.to_datetime('2018-06-01'), dynamic=False)
pred_ci = pred.conf_int()

ax = y['2015':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))

ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)

ax.set_xlabel('Fiscal Period')
ax.set_ylabel('Revenue')
plt.legend()

plt.savefig('Predicted_Rev.png')

# %%
y_forecasted = pred.predicted_mean
y_truth = y['2018-06-01':]

# Compute the mean square error
mse = ((y_forecasted - y_truth) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))
# Out:
# The Mean Squared Error of our forecasts is 5548.38

# %%
print('The Root Mean Squared Error of our forecasts is {}'.format(round(np.sqrt(mse), 2)))
# Out:
# The Root Mean Squared Error of our forecasts is 74.49

# %%
pred_uc = results.get_forecast(steps=100)
pred_ci = pred_uc.conf_int()

ax = y.plot(label='observed', figsize=(14, 7))
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Fiscal Year')
ax.set_ylabel('Revenue')

plt.legend()
plt.savefig('Predicted_Rev2.png')
